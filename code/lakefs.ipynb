# %%
import lakefs_client
from lakefs_client import models
from lakefs_client.client import LakeFSClient

# %% [markdown]
# ### Create LakeFS Client

# %%
# lakeFS credentials and endpoint
configuration = lakefs_client.Configuration()
configuration.username = 'AKIAIOSFODNN7EXAMPLE'
configuration.password = 'wJalrXUtnFEMI/K7MDENG/bPxRfiCYEXAMPLEKEY'
configuration.host = 'http://localhost:8000'

client = LakeFSClient(configuration)

# %%
configuration.verify_ssl = False

# %% [markdown]
# ### Create Repo

# %%
import boto3

s3 = boto3.client('s3')

# %%
bucket_name = 'project-bucket-uchicago-mlops'

# %%
repo = models.RepositoryCreation(name='data-repo', 
                                 storage_namespace='s3://project-bucket-uchicago-mlops'
                                 #storage_namespace='s3://storage-bucket/repos/data-repo', 
                                 default_branch='main')
client.repositories_api.create_repository(repo)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Talha\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File c:\Users\Talha\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
